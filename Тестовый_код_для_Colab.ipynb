# %% [markdown]
# <a href="https://colab.research.google.com/github/a50kv109/AAM-V1_Runtime_Telemetry/blob/main/%D0%A2%D0%B5%D1%81%D1%82%D0%BE%D0%B2%D1%8B%D0%B9_%D0%BA%D0%BE%D0%B4_%D0%B4%D0%BB%D1%8F_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Использован AAM-V1_ARTSYBASHEV_UA_KHARKIV_AIANALYSIS
# =====================================================================
# Эксперимент 1: Базовая проверка связи Google Colab -> GitHub
# Репозиторий: a50kv109/AAM-V1_Runtime_Telemetry
# =====================================================================

def test_github_connection():
    methodology_id = "AAM-V1_ARTSYBASHEV_UA_KHARKIV_AIANALYSIS"
    repo_name = "a50kv109/AAM-V1_Runtime_Telemetry"

    print("========================================")
    print("AAM-V1 test connection successful!")
    print(f"Идентификатор методологии: {methodology_id}")
    print(f"Целевой репозиторий: {repo_name}")
    print("========================================")
    print("Готово для отправки в GitHub (File -> Save a copy in GitHub)")

if __name__ == "__main__":
    test_github_connection()
